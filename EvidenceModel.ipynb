# %% [markdown]
# The purpose of this project is to fine-tune T5 model for generating evidence from the News Article.
#
# ---

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
import json

with open('/content/gdrive/MyDrive/EvidenceQuery/train.json', 'r') as f:
  train_data = json.load(f)

train_src = []
train_tgt = []

i = 0
for d in train_data:
  train_src.append(d["src"]) 
  train_tgt.append(d["evd"])
  i = i + 1
  if i >= 70000:
    break


with open('/content/gdrive/MyDrive/EvidenceQuery/val.json', 'r') as f:
  val_data = json.load(f)

val_src = []
val_tgt = []

for d in val_data:
  val_src.append(d["src"]) 
  val_tgt.append(d["evd"])

#print(train_src)
#print(train_tgt)

#print(val_src)
#print(val_tgt)

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
# !pip install transformers
# !pip install sentencepiece==0.1.91

# %%
from transformers import T5Tokenizer
import torch

class T5Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])
        return item
    def __len__(self):
        return len(self.labels['input_ids'])

tokenizer = T5Tokenizer.from_pretrained('t5-base')

def tokenize_data(texts, labels):
  encodings = tokenizer(texts,  padding=True, truncation=True)
  decodings = tokenizer(labels, padding=True)
  dataset_tokenized = T5Dataset(encodings, decodings)
  return dataset_tokenized

train_dataset = tokenize_data(train_src, train_tgt)
val_dataset = tokenize_data(val_src, val_tgt)
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments
import torch

model_name = 't5-base'

model = T5ForConditionalGeneration.from_pretrained(model_name).to(device)

training_args = TrainingArguments(
  output_dir='/content/gdrive/MyDrive/EvidenceQuery/results',
  evaluation_strategy='steps',
  eval_steps=500,
  warmup_steps=5000,
  weight_decay=0.01,
  logging_dir='/content/gdrive/MyDrive/EvidenceQuery/logs',
  logging_steps=100,
  load_best_model_at_end=True,
  
  per_device_train_batch_size=8,
  per_device_eval_batch_size=32,

)

trainer = Trainer(
  model=model,
  args=training_args,
  train_dataset=train_dataset,
  eval_dataset=val_dataset,
  tokenizer=tokenizer
)
# Out:
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
import os

trainer.train()

dir = '/content/gdrive/MyDrive/EvidenceQuery/model'

model.save_pretrained(dir)
# Out:
# ***** Running training *****
#   Num examples = 70000
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 26250
#     <div>
#
#       <progress value='26250' max='26250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26250/26250 5:44:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.931000</td>
#       <td>1.179201</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.117000</td>
#       <td>0.842306</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.018700</td>
#       <td>0.785975</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.978300</td>
#       <td>0.758993</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.954000</td>
#       <td>0.739270</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.935200</td>
#       <td>0.729296</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.930200</td>
#       <td>0.722650</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.905300</td>
#       <td>0.713448</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.885100</td>
#       <td>0.704933</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.872900</td>
#       <td>0.694572</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.882600</td>
#       <td>0.693880</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.874600</td>
#       <td>0.684600</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.874900</td>
#       <td>0.680799</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.863400</td>
#       <td>0.678238</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.865100</td>
#       <td>0.675564</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.849400</td>
#       <td>0.672228</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.831200</td>
#       <td>0.671071</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.822500</td>
#       <td>0.670034</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.834700</td>
#       <td>0.668769</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.822400</td>
#       <td>0.667204</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.802000</td>
#       <td>0.660912</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.830200</td>
#       <td>0.662351</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.816700</td>
#       <td>0.663267</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.823100</td>
#       <td>0.659369</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.800700</td>
#       <td>0.659941</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.820300</td>
#       <td>0.658061</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.812500</td>
#       <td>0.657905</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.798200</td>
#       <td>0.656938</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.798200</td>
#       <td>0.654429</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.817000</td>
#       <td>0.652776</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.821400</td>
#       <td>0.650442</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.797900</td>
#       <td>0.651541</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.800200</td>
#       <td>0.649860</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.816400</td>
#       <td>0.648812</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.786300</td>
#       <td>0.649280</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.786800</td>
#       <td>0.654133</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.780000</td>
#       <td>0.652650</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.770100</td>
#       <td>0.652726</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.774200</td>
#       <td>0.651188</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.784200</td>
#       <td>0.651483</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.776500</td>
#       <td>0.651141</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.771600</td>
#       <td>0.649569</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.756300</td>
#       <td>0.649892</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.786700</td>
#       <td>0.647919</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.759700</td>
#       <td>0.648304</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.760600</td>
#       <td>0.648963</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.751900</td>
#       <td>0.646887</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.762900</td>
#       <td>0.647319</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.746500</td>
#       <td>0.646344</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.771900</td>
#       <td>0.647058</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.773800</td>
#       <td>0.646281</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.779100</td>
#       <td>0.646531</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-1500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-2500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-3500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-4500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-5500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-6500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-7500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-8500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-9500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-10500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-11500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-12500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-13500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-14500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-15500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-16500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-17500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-18500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-19500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-20500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-21500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-22500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-23500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-24500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 1337
#   Batch size = 32
# Saving model checkpoint to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-26000/spiece.model
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500 (score: 0.6462808847427368).
# Could not locate the best model at /content/gdrive/MyDrive/EvidenceQuery/results/checkpoint-25500/pytorch_model.bin, if you are running a distributed training on multiple nodes, you should activate `--save_on_each_node`.
# Configuration saved in /content/gdrive/MyDrive/EvidenceQuery/model/config.json
# Model weights saved in /content/gdrive/MyDrive/EvidenceQuery/model/pytorch_model.bin
